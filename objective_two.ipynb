# %%
from utils import topic_graph, DataCleaner
import pandas as pd

# %%
import os
path = os.getcwd() + "/data.csv"

""" LOAD DATA SET INTO PANDAS DATAFRAME """
data_set = pd.read_csv(path)[['TITLE', 'TAG']]
data_set = data_set.drop_duplicates()

dc = DataCleaner()
data_set['TITLE'] = data_set['TITLE'] = data_set['TITLE'].apply(lambda x: dc.data_cleaning(x))

# %%
topic_graph(
    features = 1000, 
    components = 10, 
    words = 10, 
    data_set = data_set['TITLE']
)
# Out:
# /home/syedmohsinkarim/Documents/URDU_NLP/venv/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1422: FutureWarning: `alpha` was deprecated in version 1.0 and will be removed in 1.2. Use `alpha_W` and `alpha_H` instead
#   warnings.warn(
# /home/syedmohsinkarim/Documents/URDU_NLP/venv/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:289: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(
